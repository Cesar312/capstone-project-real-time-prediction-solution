# %%
import os
import sys
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

# %%
from src.paths import METRICS_DIR

# %%
file_path = METRICS_DIR / 'metrics.json'

# %%
df = pd.read_json(file_path)
df.head(10)
# Out:
#         MAE         MSE       RMSE       SMAPE         R  R-squared  \
# 0  6.520720  501.648590  22.397512  100.811052  0.907190   0.670959
# 1  4.463110  348.217682  18.660591   95.341390  0.886405   0.771597
# 2  3.835452  231.284348  15.208035  105.986428  0.921993   0.848296
# 3  3.146624  153.590317  12.393156  150.664246  0.948550   0.899257
# 4  3.024680  137.027357  11.705868  150.804252  0.954240   0.910121
#
#                               Model
# 0          Baseline (Previous Hour)
# 1          Baseline (Previous Week)
# 2  Baseline (Previous Last 4 Weeks)
# 3                           XGBoost
# 4                          LightGBM

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Model', y='MAE', data=df)
plt.title('MAE by Model')
plt.xlabel('Model')
plt.ylabel('Mean Absolute Error (MAE)')
plt.xticks(rotation=60)
plt.tight_layout
plt.show()
